# %%
import pandas as pd
import numpy as np
import os 
from sklearn.model_selection import train_test_split

# %%
pwd
# Out:
# '/home/braincreator'

# %%
#Capturing File Path
iowa_data_full = pd.read_csv('/home/braincreator/iowa/train.csv', index_col= 'Id')
iowa_data_test_full = pd.read_csv('/home/braincreator/iowa/test.csv', index_col='Id')

# %%
#Remove rows with missing target, separate target from predictions
iowa_data_full.dropna(axis=0, subset=['SalePrice'], inplace = True)
y = iowa_data_full.SalePrice
iowa_data_full.drop(['SalePrice'], axis=1, inplace = True)

# %%
iowa_data_full.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
iowa_data_full.head(5)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 2          Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 3          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 4          Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 5          Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#    MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
iowa_data_full.shape[0]
# Out:
# 1460

# %%
#Creating Train-Test Split
X_train_full, X_valid_full, y_train, y_valid = train_test_split(iowa_data_full, y, train_size = 0.8, test_size = 0.2,
                                                               random_state = 0)

# %%
#Selecting categorical columns with relatively low cardinality
categorical_lowcard_cols = [cname for cname in X_train_full.columns if 
                   X_train_full [cname].nunique()< 10 and
                   X_train_full[cname].dtype =='object']

#Selecting numerical columns
numerical_cols = [cname for cname in X_train_full.columns if
                  X_train_full[cname]. dtype in ['int64', 'float64']]

# %%
#Selected columns are now kept
my_cols = categorical_lowcard_cols + numerical_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = iowa_data_test_full[my_cols].copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_absolute_error

# %%
#Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy = 'constant')

#Preprocessing for categorical data
categorical_transformer = Pipeline(steps = [('imputer', SimpleImputer(strategy='most_frequent')),
                                           ('onehot', OneHotEncoder(handle_unknown = 'ignore'))])

# %%
#Bundling preprocessing for numrical and categorical data
preprocessor = ColumnTransformer(transformers = [
    ('num', numerical_transformer, numerical_cols),
    ('cat', categorical_transformer, categorical_lowcard_cols)])

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

#Fit with Pipeline model
my_pipeline = Pipeline(steps = [('preprocessor', preprocessor),
                                   ('model', RFR(n_estimators = 100, criterion = 'mae', random_state=0))])
my_pipeline.fit(X_train, y_train)
preds = my_pipeline.predict(X_valid)
mae = mean_absolute_error(y_valid, preds)

print ('MAE:', mae)
# Out:
# MAE: 17772.48205479452

# %%
print (my_pipeline.predict (X_valid.head(1460)))
# Out:
# [202317.84 145033.46 114737.5  235086.73  90438.   109400.05 257021.32
#  124100.16 525460.56 155692.78 197873.81 147000.58 224241.25 117207.1
#  126501.   147385.75 224312.91 119456.33 142949.   195880.7  131889.84
#  142500.   119869.56 167893.27 181553.5  216187.48 165641.32  86589.
#  327532.43 116924.37 135820.32 197716.4  144002.3  283061.08 323745.94
#  183608.95 282831.7  128373.1  233644.52 311561.79 200437.4  130235.82
#  179921.59 297565.64 324290.79 145003.39 130058.96 128402.5  165523.5
#  103278.33 358502.55 144008.5  166122.5   90550.65 244440.74 115569.16
#  136048.37 240562.99 141324.   105188.83 145218.   131388.58 144058.25
#  149926.37 198881.   162074.5  126510.33 219989.03 123663.42 186239.57
#  180609.74 122200.3   90595.65 221754.56  96046.58 259061.83 129249.
#  109128.71 278136.79 159998.15 136915.6  127831.16 128056.57 142465.17
#  182233.34 195702.26 104656.1  192203.05 173160.19 140050.33 190777.4
# ...

# %%
from sklearn.model_selection import cross_val_score as cvs

scores = -1 * cvs(my_pipeline, iowa_data_full, y,
                  cv=5,
                  scoring ='neg_mean_absolute_error')
                
print("Average MAE score:", scores.mean())
# Out:
# Average MAE score: 17762.528469178083

# %%
print ("MAE scores:\n", scores)
# Out:
# MAE scores:
#  [17548.33049658 18098.57640411 18391.84503425 16241.65967466
#  18532.2307363 ]

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

#Fit with Pipeline model
my_pipeline = Pipeline(steps = [('preprocessor', preprocessor),
                                   ('model', RFR(n_estimators = 500, criterion = 'mae', random_state=0))])
my_pipeline.fit(X_train, y_train)
preds = my_pipeline.predict(X_valid)
mae = mean_absolute_error(y_valid, preds)

print ('MAE:', mae)
# Out:
# MAE: 17726.91469178082

# %%
from sklearn.model_selection import cross_val_score as cvs

scores = -1 * cvs(my_pipeline, iowa_data_full, y,
                  cv=5,
                  scoring ='neg_mean_absolute_error')
                
print("Average MAE score:", scores.mean())
# Out:
# Average MAE score: 17719.434823287673

# %%
#Getting predictions of test data with model
preds_test = my_pipeline.predict(iowa_data_test_full)
print (my_pipeline.predict(iowa_data_test_full.head(1460)))
# Out:
# [128079.394 153733.59  183684.532 ... 153862.502 110765.74  234966.004]
